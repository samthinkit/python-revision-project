# %% [markdown]
# Python,  things that I reassure

# %%
message = """this
messeage
includes
more
than
one 
row"""
msg1= "I mean"
msg2 = "hello mf"
print(message)  
print(message.count("r"))   
print(message.find("r"))          
print(message.find("x")) # "-1" bcs no existence of "x"

msg3= "{}, {}".format(msg1,msg2)
print(msg3)

message2 = f'{msg1}, {msg2}'
print(message2)


#help function gives us help :) ==> print(help(str))

courses = ['tarih', "musik", "art", "math" ]

courses.insert(2, "biology") 
courses.append("resim")  #app end
print(courses)

courses2= [ "chemist", "art of sex" ]
courses.insert(0,courses2)

print(courses)
courses.pop(0)
courses.extend(courses2) #extend method does extend list of courses but not create list of list 
print(courses)

courses.reverse()
print(courses)
courses.sort() # sort(reverse=True) can also be possible
print(courses)

print(courses.index("resim"))
print("resim"in courses)
print("sociology" in courses)

for index, course in enumerate(courses, start=1): #or list(enumerate)
  print(index,course)

print(" % ".join(courses))
new_list = " % ".join(courses).split(" % ")
print(new_list)


###### SET #####
art_courses= {"a" , "b", "c", "d"}
math_coursrs= {"a", "k", "l", "b" }
print(art_courses.intersection(math_coursrs)) # intersect of two sets
print(art_courses.difference(math_coursrs)) # different element of art_courses
print(art_courses.union(math_coursrs)) # union of sets


#creating empty list, tuple ,set, dictionary 

empty_list = [] 
empty_list = list()
empty_set = set()
empty_dict = {}
empty_tuple = ()
empty_tuple = tuple() 


#dictionaries

students = {"ally": 404, "memo": 405, "gemr" : 897, "yusouf" : 902, "movies": "james bond", "skils": ["karate", "guitar", "programming" , "okey101"  ] }
print(students)

print(type(students.get("skils")))
students["fathername"] = "jesus"
print(students.get("fathername", "none found"))


print(students.keys()) # get keys
print(students.items()) #get items
students.update({"ally": 4040, "memo": 4050, "gemr" : 8970, "yusouf" : 9020})
print(students)

del students["skils"] #delete students skils items(key)
print(students)

students.pop("movies") #delete movies item(key) by using pop method
print(students)

for keys, items in students.items():
  print(keys, items)
  
a = ('apple', 'banana', 'cherry')
y = id(a) #uniqu id number of tuple
b = ('apple', 'banana', 'cherry') 
x = id(b) #uniqu id number of tuple
print(a==b,x==y)

# false values dor conditionally boolean are : ==> None, 0, False, "", (), [], {}

x = False
y = []
z = ()
v = {}
u= None
if x or y or z or v or u:
  print("Evaluated True" )
else:
  print("Evaluated False")

# %%
a = [1,2,3,4,5]

for i in a:
  if i ==2:
    print("2 is found")
    break
    
  print(i)  

print('#####################\n##################')
for i in a:
  if i ==2:
    print("2 is found")
    continue
    
  print(i)    

print('#####################\n##################')

x = 0
while True:
  if x == 10:
    break
  print(x)  
  x = x+1    

print('#####################\n##################')
x = 0
while True:
  if x ==10:
    break
  x = x+1 
  print(x)

# %%
def func(arg1, arg2="kestane_balının_diyarından_selamlar"):
  return "{}, {}".format(arg1,arg2)
print(func("zonguldak"))

def student_info(*args, **kwargs):  #  args nd kwargs are convention it can be any other naming
  print(kwargs)
  return (args)
  
print(student_info("050140420", "calculus", age="19",name ="meryem"  ))

def student_info(*args, **kwargs):  #  args nd kwargs are convention it can be any other naming
  print(args)
  print(kwargs)

courses = ["calculus", "history"]
info = {"age":19, "name": "meryem"}

student_info(*courses , *info)

# %%
def student_info(*args, **kwargs):  #  args and kwargs are convention it can be any other naming
  print(args)
  print(kwargs)

courses = ["calculus", "history"]
info = {"age":19, "name": "meryem"}

student_info(*courses , **info)  # courses list argument this is why it takes single star
#student_info(courses , info) gives empty dict at the end

# %%
## determining year and month number
month_days = [0,31,28,31,30,31,30,31,31,30,31,30,31]

def is_leap_year(year):
  return year % 4== 0 and (year % 100 !=0 or year % 400==0)

def days_in_month(year,month):

  if not 1<=month<=12:
    return ("invalid_month")
  if month == 2 and is_leap_year(year):
    return 29

  return month_days[month] 

print(days_in_month(2016,2))

# %%
#module that is going to be imported

print("Imported module...")

test = "Test String"
def find_index(to_search, target):

    for i, value in enumerate(to_search):
        if value == target:
            return i
    return -1

# %%
#working with modules and some comment
import sys
sys.path.append("/Users/hp/PycharmProjects/pythonProject")
import modul as m # or from modul import find_index # or from modul import *

courses = ["history", "math", "physisc", "flüt"]

index = m.find_index(courses, "flüt")
print(index)
print(m.test)

print(sys.path)

# when working directory document changes say "modul" of module then...
# changing working directory of the windows is the solution
# or you can change working environment of your windows

import random
courses = ["history", "math", "physisc", "flüt"]
random_course = random.choice(courses)
print(random_course)
